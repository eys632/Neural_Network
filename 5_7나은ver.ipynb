# %%
import numpy as np

class LinearModel:
    def __init__(self):
        np.random.seed(42)
        self.w = np.random.randn(1)
        self.b = np.zeros(1)

    def forward(self, x):
        return self.w * x + self.b
    
    def backward(self, dout):
        dx = None
        dw = None
        dy = None

        return dx, dw, dy

# %%
x = 2

model = LinearModel()

print(model.w)
print(model.b)

y = model.forward(x)
print(y)
# Out:
# [0.49671415]
# [0.]
# [0.99342831]

# %% [markdown]
# MSE 구현하기

# %%
import numpy as np

class LinearModel:
    def __init__(self):
        np.random.seed(42)
        self.w = np.random.randn(1)  # w 값을 저장
        self.b = np.zeros(1)  # b 값을 저장
        self.x = None

    def forward(self, x):
        self.x = x
        return self.w * x + self.b  # wx + b 계산 결과 반환

    def backward(self, dout):
        dx = self.w * dout  # dy(wx+b)/dx 계산 * dout # 순간변화율 구하기
        dw =  self.x * dout # d(wx+b)/dw 계산 * dout
        db = 1.0 * dout  # d(wx+b)/db 계산 * dout
        return dx, dw, db

# %%
x = 2
dout = 1

dx, dw, db = model.backward(dout)

# %%
import numpy as np

class LinearModel:
    def __init__(self):
        np.random.seed(42)
        self.w = np.random.randn(1)  # w 값을 저장
        self.b = np.zeros(1)  # b 값을 저장
        self.x = None

    def forward(self, x):
        self.x = x
        return self.w * x + self.b  # wx + b 계산 결과 반환

    def backward(self, dout):
        dx = self.w * dout  # dy(wx+b)/dx 계산 * dout # 순간변화율 구하기
        dw = self.x * dout  # d(wx+b)/dw 계산 * dout
        db = 1.0 * dout  # d(wx+b)/db 계산 * dout
        return dx, dw, db

# 평균제곱오차 (MSE) 정의
class MeanSquaredError:
    def __init__(self):
        self.y = None
        self.t = None

    def forward(self, y, t):
        self.y = y
        self.t = t
        return 0.5 * (y - t) ** 2
    
    def backward(self, dout=1):
        return (self.y - self.t) * dout

# %%
# Create an instance of LinearModel
model = LinearModel()

# Sample input
x_input = 2  # Input value for forward pass
dout = 1  # Example output gradient

# Perform the forward pass first to set the x value
y = model.forward(x_input)

# Calculate backward gradients
dx, dw, db = model.backward(dout)

print(dx)
print(dw)
print(db)
# Out:
# [0.49671415]
# 2
# 1.0

# %%
# 테스트용 입력값
x = 2
t = 1

# 모델 예측 및 손실 계산
model1 = LinearModel()
y = model1.forward(x)

mse = MeanSquaredError()
loss = mse.forward(y, t)

print("Loss:", loss)
# Out:
# Loss: [2.15935809e-05]

# %%
dout = mse.backward()
print(dout)
# Out:
# [-0.00657169]

# %% [markdown]
# $$L = 1/2 * (y-t) ** 2$$

# %%
dx, dw, dy = model.backward(dout = dout)
print(dx)
print(dw)
print(dy)
# Out:
# [-0.00326425]
# [-0.01314339]
# [-0.00657169]

# %%
x = 2
t = 1
lr = 0.01

model = LinearModel()
mse = MeanSquaredError()

print(model.w)
print(model.b)
# Out:
# [0.49671415]
# [0.]

# %%
out = model.forward(x)
print(out)

out = mse.forward(y = out, t = t)
print(out)
# Out:
# [0.99342831]
# [2.15935809e-05]

# %%
dout = mse.backward()
print(dout)

dx, dw, db = model.backward(dout = dout)
print(dx)
print(dw)
print(db)
# Out:
# [-0.00657169]
# [-0.00326425]
# [-0.01314339]
# [-0.00657169]

# %%
model.w = model.w - lr * dw
model.b = model.b - lr * db

print(model.w)
print(model.b)
# Out:
# [0.49684559]
# [6.57169398e-05]

# %%
out = model.forward(x)
print(out)

out = mse.forward(y = out, t = t)
print(out)
# Out:
# [0.99375689]
# [1.94882067e-05]

# %%
for i in range(100):
    out = model.forward(x)
    print("{}번째 전파 출력값: {}".format(i, out))

    out = mse.forward(y = out, t=t)
    print("{}번째 손실함수 값: {}".format(i, out))

    dout = mse.backward()
    dx, dw, db = model.backward(dout = dout)

    model.w = model.w - lr * dw
    model.b = model.b - lr * db
# Out:
# 0번째 전파 출력값: [0.99375689]
# 0번째 손실함수 값: [1.94882067e-05]
# 1번째 전파 출력값: [0.99406905]
# 1번째 손실함수 값: [1.75881066e-05]
# 2번째 전파 출력값: [0.99436559]
# 2번째 손실함수 값: [1.58732662e-05]
# 3번째 전파 출력값: [0.99464731]
# 3번째 손실함수 값: [1.43256227e-05]
# 4번째 전파 출력값: [0.99491495]
# 4번째 손실함수 값: [1.29288745e-05]
# 5번째 전파 출력값: [0.9951692]
# 5번째 손실함수 값: [1.16683093e-05]
# 6번째 전파 출력값: [0.99541074]
# 6번째 손실함수 값: [1.05306491e-05]
# 7번째 전파 출력값: [0.9956402]
# 7번째 손실함수 값: [9.50391081e-06]
# 8번째 전파 출력값: [0.99585819]
# 8번째 손실함수 값: [8.57727951e-06]
# 9번째 전파 출력값: [0.99606528]
# 9번째 손실함수 값: [7.74099476e-06]
# 10번째 전파 출력값: [0.99626202]
# 10번째 손실함수 값: [6.98624777e-06]
# 11번째 전파 출력값: [0.99644892]
# 11번째 손실함수 값: [6.30508861e-06]
# 12번째 전파 출력값: [0.99662647]
# 12번째 손실함수 값: [5.69034247e-06]
# 13번째 전파 출력값: [0.99679515]
# 13번째 손실함수 값: [5.13553408e-06]
# 14번째 전파 출력값: [0.99695539]
# 14번째 손실함수 값: [4.63481951e-06]
# 15번째 전파 출력값: [0.99710762]
# 15번째 손실함수 값: [4.1829246e-06]
# 16번째 전파 출력값: [0.99725224]
# 16번째 손실함수 값: [3.77508946e-06]
# 17번째 전파 출력값: [0.99738963]
# 17번째 손실함수 값: [3.40701823e-06]
# 18번째 전파 출력값: [0.99752015]
# 18번째 손실함수 값: [3.07483396e-06]
# 19번째 전파 출력값: [0.99764414]
# 19번째 손실함수 값: [2.77503765e-06]
# 20번째 전파 출력값: [0.99776193]
# 20번째 손실함수 값: [2.50447147e-06]
# 21번째 전파 출력값: [0.99787384]
# 21번째 손실함수 값: [2.26028551e-06]
# 22번째 전파 출력값: [0.99798014]
# 22번째 손실함수 값: [2.03990767e-06]
# 23번째 전파 출력값: [0.99808114]
# 23번째 손실함수 값: [1.84101667e-06]
# 24번째 전파 출력값: [0.99817708]
# 24번째 손실함수 값: [1.66151755e-06]
# 25번째 전파 출력값: [0.99826823]
# 25번째 손실함수 값: [1.49951959e-06]
# 26번째 전파 출력값: [0.99835482]
# 26번째 손실함수 값: [1.35331643e-06]
# 27번째 전파 출력값: [0.99843707]
# 27번째 손실함수 값: [1.22136807e-06]
# 28번째 전파 출력값: [0.99851522]
# 28번째 손실함수 값: [1.10228469e-06]
# 29번째 전파 출력값: [0.99858946]
# 29번째 손실함수 값: [9.9481193e-07]
# 30번째 전파 출력값: [0.99865999]
# 30번째 손실함수 값: [8.97817767e-07]
# 31번째 전파 출력값: [0.99872699]
# 31번째 손실함수 값: [8.10280535e-07]
# 32번째 전파 출력값: [0.99879064]
# 32번째 손실함수 값: [7.31278182e-07]
# 33번째 전파 출력값: [0.99885111]
# 33번째 손실함수 값: [6.5997856e-07]
# 34번째 전파 출력값: [0.99890855]
# 34번째 손실함수 값: [5.9563065e-07]
# 35번째 전파 출력값: [0.99896312]
# 35번째 손실함수 값: [5.37556662e-07]
# 36번째 전파 출력값: [0.99901497]
# 36번째 손실함수 값: [4.85144887e-07]
# 37번째 전파 출력값: [0.99906422]
# 37번째 손실함수 값: [4.37843261e-07]
# 38번째 전파 출력값: [0.99911101]
# 38번째 손실함수 값: [3.95153543e-07]
# 39번째 전파 출력값: [0.99915546]
# 39번째 손실함수 값: [3.56626072e-07]
# 40번째 전파 출력값: [0.99919768]
# 40번째 손실함수 값: [3.2185503e-07]
# 41번째 전파 출력값: [0.9992378]
# 41번째 손실함수 값: [2.90474165e-07]
# 42번째 전파 출력값: [0.99927591]
# 42번째 손실함수 값: [2.62152934e-07]
# 43번째 전파 출력값: [0.99931211]
# 43번째 손실함수 값: [2.36593023e-07]
# 44번째 전파 출력값: [0.99934651]
# 44번째 손실함수 값: [2.13525203e-07]
# 45번째 전파 출력값: [0.99937918]
# 45번째 손실함수 값: [1.92706496e-07]
# 46번째 전파 출력값: [0.99941022]
# 46번째 손실함수 값: [1.73917612e-07]
# 47번째 전파 출력값: [0.99943971]
# 47번째 손실함수 값: [1.56960645e-07]
# 48번째 전파 출력값: [0.99946773]
# 48번째 손실함수 값: [1.41656982e-07]
# 49번째 전파 출력값: [0.99949434]
# 49번째 손실함수 값: [1.27845426e-07]
# 50번째 전파 출력값: [0.99951962]
# 50번째 손실함수 값: [1.15380497e-07]
# 51번째 전파 출력값: [0.99954364]
# 51번째 손실함수 값: [1.04130899e-07]
# 52번째 전파 출력값: [0.99956646]
# 52번째 손실함수 값: [9.39781363e-08]
# 53번째 전파 출력값: [0.99958814]
# 53번째 손실함수 값: [8.4815268e-08]
# 54번째 전파 출력값: [0.99960873]
# 54번째 손실함수 값: [7.65457794e-08]
# 55번째 전파 출력값: [0.99962829]
# 55번째 손실함수 값: [6.90825659e-08]
# 56번째 전파 출력값: [0.99964688]
# 56번째 손실함수 값: [6.23470157e-08]
# 57번째 전파 출력값: [0.99966454]
# 57번째 손실함수 값: [5.62681817e-08]
# 58번째 전파 출력값: [0.99968131]
# 58번째 손실함수 값: [5.0782034e-08]
# 59번째 전파 출력값: [0.99969724]
# 59번째 손실함수 값: [4.58307856e-08]
# 60번째 전파 출력값: [0.99971238]
# 60번째 손실함수 값: [4.1362284e-08]
# 61번째 전파 출력값: [0.99972676]
# 61번째 손실함수 값: [3.73294613e-08]
# 62번째 전파 출력값: [0.99974042]
# 62번째 손실함수 값: [3.36898389e-08]
# 63번째 전파 출력값: [0.9997534]
# 63번째 손실함수 값: [3.04050796e-08]
# 64번째 전파 출력값: [0.99976573]
# 64번째 손실함수 값: [2.74405843e-08]
# 65번째 전파 출력값: [0.99977745]
# 65번째 손실함수 값: [2.47651273e-08]
# 66번째 전파 출력값: [0.99978857]
# 66번째 손실함수 값: [2.23505274e-08]
# 67번째 전파 출력값: [0.99979915]
# 67번째 손실함수 값: [2.0171351e-08]
# 68번째 전파 출력값: [0.99980919]
# 68번째 손실함수 값: [1.82046443e-08]
# 69번째 전파 출력값: [0.99981873]
# 69번째 손실함수 값: [1.64296915e-08]
# 70번째 전파 출력값: [0.99982779]
# 70번째 손실함수 값: [1.48277965e-08]
# 71번째 전파 출력값: [0.9998364]
# 71번째 손실함수 값: [1.33820864e-08]
# 72번째 전파 출력값: [0.99984458]
# 72번째 손실함수 값: [1.2077333e-08]
# 73번째 전파 출력값: [0.99985235]
# 73번째 손실함수 값: [1.0899793e-08]
# 74번째 전파 출력값: [0.99985974]
# 74번째 손실함수 값: [9.83706318e-09]
# 75번째 전파 출력값: [0.99986675]
# 75번째 손실함수 값: [8.87794952e-09]
# 76번째 전파 출력값: [0.99987341]
# 76번째 손실함수 값: [8.01234944e-09]
# 77번째 전파 출력값: [0.99987974]
# 77번째 손실함수 값: [7.23114537e-09]
# 78번째 전파 출력값: [0.99988575]
# 78번째 손실함수 값: [6.5261087e-09]
# 79번째 전파 출력값: [0.99989147]
# 79번째 손실함수 값: [5.8898131e-09]
# 80번째 전파 출력값: [0.99989689]
# 80번째 손실함수 값: [5.31555632e-09]
# 81번째 전파 출력값: [0.99990205]
# 81번째 손실함수 값: [4.79728958e-09]
# 82번째 전파 출력값: [0.99990695]
# 82번째 손실함수 값: [4.32955385e-09]
# 83번째 전파 출력값: [0.9999116]
# 83번째 손실함수 값: [3.90742235e-09]
# 84번째 전파 출력값: [0.99991602]
# 84번째 손실함수 값: [3.52644867e-09]
# 85번째 전파 출력값: [0.99992022]
# 85번째 손실함수 값: [3.18261992e-09]
# 86번째 전파 출력값: [0.99992421]
# 86번째 손실함수 값: [2.87231448e-09]
# 87번째 전파 출력값: [0.999928]
# 87번째 손실함수 값: [2.59226382e-09]
# 88번째 전파 출력값: [0.9999316]
# 88번째 손실함수 값: [2.3395181e-09]
# 89번째 전파 출력값: [0.99993502]
# 89번째 손실함수 값: [2.11141508e-09]
# 90번째 전파 출력값: [0.99993827]
# 90번째 손실함수 값: [1.90555211e-09]
# 91번째 전파 출력값: [0.99994135]
# 91번째 손실함수 값: [1.71976078e-09]
# 92번째 전파 출력값: [0.99994428]
# 92번째 손실함수 값: [1.5520841e-09]
# 93번째 전파 출력값: [0.99994707]
# 93번째 손실함수 값: [1.4007559e-09]
# 94번째 전파 출력값: [0.99994972]
# 94번째 손실함수 값: [1.2641822e-09]
# 95번째 전파 출력값: [0.99995223]
# 95번째 손실함수 값: [1.14092444e-09]
# 96번째 전파 출력값: [0.99995462]
# 96번째 손실함수 값: [1.02968431e-09]
# 97번째 전파 출력값: [0.99995689]
# 97번째 손실함수 값: [9.29290086e-10]
# 98번째 전파 출력값: [0.99995904]
# 98번째 손실함수 값: [8.38684303e-10]
# 99번째 전파 출력값: [0.99996109]
# 99번째 손실함수 값: [7.56912583e-10]

# %%
for i in range(100):
    out = model.forward(x)
    print("{}번째 전파 출력값 : {}".format(i, out))

    out = mse.forward(y=out, t=t)    
    print("{}번째 손실함수 출력값 : {}".format(i, out))

    dout = mse.backward()
    dx, dw, db = model.backward(dout=dout)

    model.w -= lr * dw
    model.b -= lr * db
    print("{}번째 가중치 : {}".format(i, model.w))
# Out:
# 0번째 전파 출력값 : [0.99999978]
# 0번째 손실함수 출력값 : [2.39449533e-14]
# 0번째 가중치 : [0.49934275]
# 1번째 전파 출력값 : [0.99999979]
# 1번째 손실함수 출력값 : [2.16103203e-14]
# 1번째 가중치 : [0.49934275]
# 2번째 전파 출력값 : [0.9999998]
# 2번째 손실함수 출력값 : [1.95033141e-14]
# 2번째 가중치 : [0.49934276]
# 3번째 전파 출력값 : [0.99999981]
# 3번째 손실함수 출력값 : [1.7601741e-14]
# 3번째 가중치 : [0.49934276]
# 4번째 전파 출력값 : [0.99999982]
# 4번째 손실함수 출력값 : [1.58855712e-14]
# 4번째 가중치 : [0.49934276]
# 5번째 전파 출력값 : [0.99999983]
# 5번째 손실함수 출력값 : [1.4336728e-14]
# 5번째 가중치 : [0.49934277]
# 6번째 전파 출력값 : [0.99999984]
# 6번째 손실함수 출력값 : [1.2938897e-14]
# 6번째 가중치 : [0.49934277]
# 7번째 전파 출력값 : [0.99999985]
# 7번째 손실함수 출력값 : [1.16773546e-14]
# 7번째 가중치 : [0.49934277]
# 8번째 전파 출력값 : [0.99999985]
# 8번째 손실함수 출력값 : [1.05388125e-14]
# 8번째 가중치 : [0.49934278]
# 9번째 전파 출력값 : [0.99999986]
# 9번째 손실함수 출력값 : [9.51127826e-15]
# 9번째 가중치 : [0.49934278]
# 10번째 전파 출력값 : [0.99999987]
# 10번째 손실함수 출력값 : [8.58392863e-15]
# 10번째 가중치 : [0.49934278]
# 11번째 전파 출력값 : [0.99999988]
# 11번째 손실함수 출력값 : [7.74699559e-15]
# 11번째 가중치 : [0.49934278]
# 12번째 전파 출력값 : [0.99999988]
# 12번째 손실함수 출력값 : [6.99166352e-15]
# 12번째 가중치 : [0.49934279]
# 13번째 전파 출력값 : [0.99999989]
# 13번째 손실함수 출력값 : [6.30997633e-15]
# 13번째 가중치 : [0.49934279]
# 14번째 전파 출력값 : [0.99999989]
# 14번째 손실함수 출력값 : [5.69475364e-15]
# 14번째 가중치 : [0.49934279]
# 15번째 전파 출력값 : [0.9999999]
# 15번째 손실함수 출력값 : [5.13951516e-15]
# 15번째 가중치 : [0.49934279]
# 16번째 전파 출력값 : [0.9999999]
# 16번째 손실함수 출력값 : [4.63841243e-15]
# 16번째 가중치 : [0.49934279]
# 17번째 전파 출력값 : [0.99999991]
# 17번째 손실함수 출력값 : [4.18616722e-15]
# 17번째 가중치 : [0.4993428]
# 18번째 전파 출력값 : [0.99999991]
# 18번째 손실함수 출력값 : [3.77801592e-15]
# 18번째 가중치 : [0.4993428]
# 19번째 전파 출력값 : [0.99999992]
# 19번째 손실함수 출력값 : [3.40965936e-15]
# 19번째 가중치 : [0.4993428]
# 20번째 전파 출력값 : [0.99999992]
# 20번째 손실함수 출력값 : [3.07721758e-15]
# 20번째 가중치 : [0.4993428]
# 21번째 전파 출력값 : [0.99999993]
# 21번째 손실함수 출력값 : [2.77718886e-15]
# 21번째 가중치 : [0.4993428]
# 22번째 전파 출력값 : [0.99999993]
# 22번째 손실함수 출력값 : [2.50641295e-15]
# 22번째 가중치 : [0.4993428]
# 23번째 전파 출력값 : [0.99999993]
# 23번째 손실함수 출력값 : [2.26203769e-15]
# 23번째 가중치 : [0.49934281]
# 24번째 전파 출력값 : [0.99999994]
# 24번째 손실함수 출력값 : [2.04148901e-15]
# 24번째 가중치 : [0.49934281]
# 25번째 전파 출력값 : [0.99999994]
# 25번째 손실함수 출력값 : [1.84244384e-15]
# 25번째 가중치 : [0.49934281]
# 26번째 전파 출력값 : [0.99999994]
# 26번째 손실함수 출력값 : [1.66280557e-15]
# 26번째 가중치 : [0.49934281]
# 27번째 전파 출력값 : [0.99999995]
# 27번째 손실함수 출력값 : [1.50068202e-15]
# 27번째 가중치 : [0.49934281]
# 28번째 전파 출력값 : [0.99999995]
# 28번째 손실함수 출력값 : [1.35436552e-15]
# 28번째 가중치 : [0.49934281]
# 29번째 전파 출력값 : [0.99999995]
# 29번째 손실함수 출력값 : [1.22231489e-15]
# 29번째 가중치 : [0.49934281]
# 30번째 전파 출력값 : [0.99999995]
# 30번째 손실함수 출력값 : [1.10313919e-15]
# 30번째 가중치 : [0.49934281]
# 31번째 전파 출력값 : [0.99999996]
# 31번째 손실함수 출력값 : [9.95583115e-16]
# 31번째 가중치 : [0.49934281]
# 32번째 전파 출력값 : [0.99999996]
# 32번째 손실함수 출력값 : [8.98513757e-16]
# 32번째 가중치 : [0.49934281]
# 33번째 전파 출력값 : [0.99999996]
# 33번째 손실함수 출력값 : [8.10908665e-16]
# 33번째 가중치 : [0.49934282]
# 34번째 전파 출력값 : [0.99999996]
# 34번째 손실함수 출력값 : [7.31845067e-16]
# 34번째 가중치 : [0.49934282]
# 35번째 전파 출력값 : [0.99999996]
# 35번째 손실함수 출력값 : [6.60490178e-16]
# 35번째 가중치 : [0.49934282]
# 36번째 전파 출력값 : [0.99999997]
# 36번째 손실함수 출력값 : [5.96092385e-16]
# 36번째 가중치 : [0.49934282]
# 37번째 전파 출력값 : [0.99999997]
# 37번째 손실함수 출력값 : [5.37973377e-16]
# 37번째 가중치 : [0.49934282]
# 38번째 전파 출력값 : [0.99999997]
# 38번째 손실함수 출력값 : [4.85520971e-16]
# 38번째 가중치 : [0.49934282]
# 39번째 전파 출력값 : [0.99999997]
# 39번째 손실함수 출력값 : [4.38182679e-16]
# 39번째 가중치 : [0.49934282]
# 40번째 전파 출력값 : [0.99999997]
# 40번째 손실함수 출력값 : [3.95459868e-16]
# 40번째 가중치 : [0.49934282]
# 41번째 전파 출력값 : [0.99999997]
# 41번째 손실함수 출력값 : [3.56902528e-16]
# 41번째 가중치 : [0.49934282]
# 42번째 전파 출력값 : [0.99999997]
# 42번째 손실함수 출력값 : [3.22104531e-16]
# 42번째 가중치 : [0.49934282]
# 43번째 전파 출력값 : [0.99999998]
# 43번째 손실함수 출력값 : [2.90699338e-16]
# 43번째 가중치 : [0.49934282]
# 44번째 전파 출력값 : [0.99999998]
# 44번째 손실함수 출력값 : [2.62356153e-16]
# 44번째 가중치 : [0.49934282]
# 45번째 전파 출력값 : [0.99999998]
# 45번째 손실함수 출력값 : [2.36776429e-16]
# 45번째 가중치 : [0.49934282]
# 46번째 전파 출력값 : [0.99999998]
# 46번째 손실함수 출력값 : [2.13690726e-16]
# 46번째 가중치 : [0.49934282]
# 47번째 전파 출력값 : [0.99999998]
# 47번째 손실함수 출력값 : [1.92855883e-16]
# 47번째 가중치 : [0.49934282]
# 48번째 전파 출력값 : [0.99999998]
# 48번째 손실함수 출력값 : [1.74052433e-16]
# 48번째 가중치 : [0.49934282]
# 49번째 전파 출력값 : [0.99999998]
# 49번째 손실함수 출력값 : [1.57082321e-16]
# 49번째 가중치 : [0.49934282]
# 50번째 전파 출력값 : [0.99999998]
# 50번째 손실함수 출력값 : [1.41766794e-16]
# 50번째 가중치 : [0.49934282]
# 51번째 전파 출력값 : [0.99999998]
# 51번째 손실함수 출력값 : [1.27944532e-16]
# 51번째 가중치 : [0.49934282]
# 52번째 전파 출력값 : [0.99999998]
# 52번째 손실함수 출력값 : [1.1546994e-16]
# 52번째 가중치 : [0.49934282]
# 53번째 전파 출력값 : [0.99999999]
# 53번째 손실함수 출력값 : [1.04211621e-16]
# 53번째 가중치 : [0.49934283]
# 54번째 전파 출력값 : [0.99999999]
# 54번째 손실함수 출력값 : [9.40509889e-17]
# 54번째 가중치 : [0.49934283]
# 55번째 전파 출력값 : [0.99999999]
# 55번째 손실함수 출력값 : [8.48810179e-17]
# 55번째 가중치 : [0.49934283]
# 56번째 전파 출력값 : [0.99999999]
# 56번째 손실함수 출력값 : [7.6605119e-17]
# 56번째 가중치 : [0.49934283]
# 57번째 전파 출력값 : [0.99999999]
# 57번째 손실함수 출력값 : [6.91361201e-17]
# 57번째 가중치 : [0.49934283]
# 58번째 전파 출력값 : [0.99999999]
# 58번째 손실함수 출력값 : [6.23953478e-17]
# 58번째 가중치 : [0.49934283]
# 59번째 전파 출력값 : [0.99999999]
# 59번째 손실함수 출력값 : [5.63118016e-17]
# 59번째 가중치 : [0.49934283]
# 60번째 전파 출력값 : [0.99999999]
# 60번째 손실함수 출력값 : [5.08214011e-17]
# 60번째 가중치 : [0.49934283]
# 61번째 전파 출력값 : [0.99999999]
# 61번째 손실함수 출력값 : [4.58663151e-17]
# 61번째 가중치 : [0.49934283]
# 62번째 전파 출력값 : [0.99999999]
# 62번째 손실함수 출력값 : [4.13943488e-17]
# 62번째 가중치 : [0.49934283]
# 63번째 전파 출력값 : [0.99999999]
# 63번째 손실함수 출력값 : [3.73583993e-17]
# 63번째 가중치 : [0.49934283]
# 64번째 전파 출력값 : [0.99999999]
# 64번째 손실함수 출력값 : [3.37159555e-17]
# 64번째 가중치 : [0.49934283]
# 65번째 전파 출력값 : [0.99999999]
# 65번째 손실함수 출력값 : [3.04286498e-17]
# 65번째 가중치 : [0.49934283]
# 66번째 전파 출력값 : [0.99999999]
# 66번째 손실함수 출력값 : [2.74618565e-17]
# 66번째 가중치 : [0.49934283]
# 67번째 전파 출력값 : [0.99999999]
# 67번째 손실함수 출력값 : [2.47843253e-17]
# 67번째 가중치 : [0.49934283]
# 68번째 전파 출력값 : [0.99999999]
# 68번째 손실함수 출력값 : [2.23678533e-17]
# 68번째 가중치 : [0.49934283]
# 69번째 전파 출력값 : [0.99999999]
# 69번째 손실함수 출력값 : [2.01869881e-17]
# 69번째 가중치 : [0.49934283]
# 70번째 전파 출력값 : [0.99999999]
# 70번째 손실함수 출력값 : [1.82187572e-17]
# 70번째 가중치 : [0.49934283]
# 71번째 전파 출력값 : [0.99999999]
# 71번째 손실함수 출력값 : [1.64424284e-17]
# 71번째 가중치 : [0.49934283]
# 72번째 전파 출력값 : [0.99999999]
# 72번째 손실함수 출력값 : [1.48392914e-17]
# 72번째 가중치 : [0.49934283]
# 73번째 전파 출력값 : [0.99999999]
# 73번째 손실함수 출력값 : [1.33924607e-17]
# 73번째 가중치 : [0.49934283]
# 74번째 전파 출력값 : [1.]
# 74번째 손실함수 출력값 : [1.20866957e-17]
# 74번째 가중치 : [0.49934283]
# 75번째 전파 출력값 : [1.]
# 75번째 손실함수 출력값 : [1.09082427e-17]
# 75번째 가중치 : [0.49934283]
# 76번째 전파 출력값 : [1.]
# 76번째 손실함수 출력값 : [9.84468891e-18]
# 76번째 가중치 : [0.49934283]
# 77번째 전파 출력값 : [1.]
# 77번째 손실함수 출력값 : [8.88483146e-18]
# 77번째 가중치 : [0.49934283]
# 78번째 전파 출력값 : [1.]
# 78번째 손실함수 출력값 : [8.01856035e-18]
# 78번째 가중치 : [0.49934283]
# 79번째 전파 출력값 : [1.]
# 79번째 손실함수 출력값 : [7.23675086e-18]
# 79번째 가중치 : [0.49934283]
# 80번째 전파 출력값 : [1.]
# 80번째 손실함수 출력값 : [6.53116723e-18]
# 80번째 가중치 : [0.49934283]
# 81번째 전파 출력값 : [1.]
# 81번째 손실함수 출력값 : [5.89437854e-18]
# 81번째 가중치 : [0.49934283]
# 82번째 전파 출력값 : [1.]
# 82번째 손실함수 출력값 : [5.31967667e-18]
# 82번째 가중치 : [0.49934283]
# 83번째 전파 출력값 : [1.]
# 83번째 손실함수 출력값 : [4.80100823e-18]
# 83번째 가중치 : [0.49934283]
# 84번째 전파 출력값 : [1.]
# 84번째 손실함수 출력값 : [4.33290988e-18]
# 84번째 가중치 : [0.49934283]
# 85번째 전파 출력값 : [1.]
# 85번째 손실함수 출력값 : [3.91045118e-18]
# 85번째 가중치 : [0.49934283]
# 86번째 전파 출력값 : [1.]
# 86번째 손실함수 출력값 : [3.52918222e-18]
# 86번째 가중치 : [0.49934283]
# 87번째 전파 출력값 : [1.]
# 87번째 손실함수 출력값 : [3.18508711e-18]
# 87번째 가중치 : [0.49934283]
# 88번째 전파 출력값 : [1.]
# 88번째 손실함수 출력값 : [2.87454104e-18]
# 88번째 가중치 : [0.49934283]
# 89번째 전파 출력값 : [1.]
# 89번째 손실함수 출력값 : [2.5942733e-18]
# 89번째 가중치 : [0.49934283]
# 90번째 전파 출력값 : [1.]
# 90번째 손실함수 출력값 : [2.34133167e-18]
# 90번째 가중치 : [0.49934283]
# 91번째 전파 출력값 : [1.]
# 91번째 손실함수 출력값 : [2.11305178e-18]
# 91번째 가중치 : [0.49934283]
# 92번째 전파 출력값 : [1.]
# 92번째 손실함수 출력값 : [1.90702901e-18]
# 92번째 가중치 : [0.49934283]
# 93번째 전파 출력값 : [1.]
# 93번째 손실함수 출력값 : [1.72109381e-18]
# 93번째 가중치 : [0.49934283]
# 94번째 전파 출력값 : [1.]
# 94번째 손실함수 출력값 : [1.55328733e-18]
# 94번째 가중치 : [0.49934283]
# 95번째 전파 출력값 : [1.]
# 95번째 손실함수 출력값 : [1.40184162e-18]
# 95번째 가중치 : [0.49934283]
# 96번째 전파 출력값 : [1.]
# 96번째 손실함수 출력값 : [1.26516221e-18]
# 96번째 가중치 : [0.49934283]
# 97번째 전파 출력값 : [1.]
# 97번째 손실함수 출력값 : [1.14180895e-18]
# 97번째 가중치 : [0.49934283]
# 98번째 전파 출력값 : [1.]
# 98번째 손실함수 출력값 : [1.03048257e-18]
# 98번째 가중치 : [0.49934283]
# 99번째 전파 출력값 : [1.]
# 99번째 손실함수 출력값 : [9.30010447e-19]
# 99번째 가중치 : [0.49934283]
